# %% [markdown]
# # 서울 자치구 주유소

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %% [markdown]
# ## 데이터 찾기

# %%
# 드라이버로 링크 열기
url = 'https://www.opinet.co.kr/user/main/mainView.do'
driver = webdriver.Chrome('chromedriver')
driver.get(url)
time.sleep(2)

# %%
# '싼 주유소 찾기' 페이지 열기
driver.find_element(By.CSS_SELECTOR, '.m1').click()

# %%
# 강남구 주유소
driver.find_element(By.XPATH, '//*[@id="SIGUNGU_NM0"]/option[2]').click()
driver.find_element(By.ID, 'glopopd_excel').click()

# %%
# 서울 모든 자치구 주유소
for i in range(2, 27):
    driver.find_element(By.XPATH, f'//*[@id="SIGUNGU_NM0"]/option[{i}]').click()
    driver.find_element(By.ID, 'glopopd_excel').click()

# %%
# 첫번째 엑셀 데이터 프레임으로 변환
df = pd.read_excel('C:/Users/user/Downloads/지역_위치별(주유소).xls', header=2)

# %%
# 엑셀 파일 불러와서 데이터 프레임에 추가하기
for i in range(1, 25):
    df_temp = pd.read_excel(f'C:/Users/user/Downloads/지역_위치별(주유소) ({i}).xls', header=2)
    df = pd.concat([df, df_temp])

# %%
# 인덱스 지정
df.set_index([pd.Index(range(443))], inplace=True)

# %%
df = df.loc[:,['상호', '주소', '상표', '셀프여부', '휘발유']]

# %%
df.rename(columns = {'휘발유':'가격'}, inplace = True)

# %%
# 저렴한 주유소 Top5
df_cheap = df.sort_values(by=['가격']).head(5)
df_cheap
# Out:
#                   상호                     주소      상표 셀프여부    가격
# 60            화곡역주유소   서울 강서구 강서로 154 (화곡동)   알뜰주유소    Y  1485
# 59   이케이에너지(주) 강서주유소   서울 강서구 화곡로 273 (화곡동)  현대오일뱅크    Y  1485
# 61            뉴신정주유소  서울 강서구 곰달래로 207 (화곡동)   알뜰주유소    N  1498
# 207          마포시엠주유소        서울 마포구 월드컵북로 62   SK에너지    N  1507
# 208        성산대교셀프주유소         서울 마포구 성산로 144  현대오일뱅크    Y  1507

# %%
# 비싼 주유소 Top5
df_exp = df.sort_values(by=['가격']).tail(5)
df_exp
# Out:
#                      상호                     주소      상표 셀프여부    가격
# 31   (주)새서울네트웍스 제이제이주유소         서울 강남구 언주로 716  현대오일뱅크    N  2298
# 428               필동주유소   서울 중구 퇴계로 196 (필동2가)   GS칼텍스    N  2419
# 32       (주)만정에너지 삼보주유소  서울 강남구 봉은사로 433 (삼성동)   GS칼텍스    N  2578
# 395               서계주유소  서울 용산구  청파로 367 (청파동)   GS칼텍스    N  2625
# 429               서남주유소           서울 중구 통일로 30   SK에너지    N  2631

# %% [markdown]
# ## 지도 시각화

# %%
import folium
import json
from urllib.parse import quote

# %%
# api 키 불러오기
with open('카톡_api_key.txt') as f:
    api_key = f.read()

# %%
search_url = "https://dapi.kakao.com/v2/local/search/address.json"

# %% [markdown]
# ### 지도 표시

# %%
# 지도
map = folium.Map(location=[37.581, 126.986], zoom_start=11)

for i in df.index:
    try:
        road_addr = df['주소'].loc[i]
        station_name = df['상호'].loc[i]
        station_type = df['상표'].loc[i]
        url = f'{search_url}?query={quote(road_addr)}'
        result = requests.get(url, headers={"Authorization": f"KakaoAK {api_key}"}).json()
        lng = float(result['documents'][0]['x'])
        lat = float(result['documents'][0]['y'])
        folium.Marker(
            location = [lat, lng], 
            popup = folium.Popup(road_addr, max_width=200),
            tooltip = (station_name+f"({station_type})"), 
            icon = folium.Icon(color = 'green', icon = 'glyphicon glyphicon-tint')
        ).add_to(map)
    except:
        print(station_name)
title = "<h3 align = 'center' style = 'font-size:20px'> 서울자치구 주유소 위치</h3>"
map.get_root().html.add_child(folium.Element(title))
map
# Out:
# (주)만성상사 대흥주유소
# 성원이앤에스(주)영등포지점
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fba17acabbbbdbb4a39676cd080858a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align = &#x27;center&#x27; style = &#x27;font-size:20px&#x27;&gt; 서울자치구 주유소 위치&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fba17acabbbbdbb4a39676cd080858a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fba17acabbbbdbb4a39676cd080858a1 = L.map(
#                 &quot;map_fba17acabbbbdbb4a39676cd080858a1&quot;,
#                 {
#                     center: [37.581, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_066c9c73c1639ac0cffc38e381eb37cf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fba17acabbbbdbb4a39676cd080858a1);
#
#
#             var marker_d1573b4b085fe51e11a8064678bd2c61 = L.marker(
#                 [37.4672717183911, 127.118742598267],
#                 {}
#             ).addTo(map_fba17acabbbbdbb4a39676cd080858a1);
#
#
#             var icon_1e652637ca2d5dd36fa42dad10e589de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1573b4b085fe51e11a8064678bd2c61.setIcon(icon_1e652637ca2d5dd36fa42dad10e589de);
#
#
#         var popup_4855fe1776771f715821d374e6f7ffc0 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_e6a0954bb07ccd4fe8679011c9f99623 = $(`&lt;div id=&quot;html_e6a0954bb07ccd4fe8679011c9f99623&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 강남구  헌릉로 731 (세곡동)&lt;/div&gt;`)[0];
#                 popup_4855fe1776771f715821d374e6f7ffc0.setContent(html_e6a0954bb07ccd4fe8679011c9f99623);
#
#
#
#         marker_d1573b4b085fe51e11a8064678bd2c61.bindPopup(popup_4855fe1776771f715821d374e6f7ffc0)
#         ;
#
#
#
#
#             marker_d1573b4b085fe51e11a8064678bd2c61.bindTooltip(
#                 `&lt;div&gt;
#                      (주)보성 세곡주유소(SK에너지)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aeaa4714a00d945ba6b32b9e2c00a278 = L.marker(
#                 [37.4854150814069, 127.043319375098],
#                 {}
#             ).addTo(map_fba17acabbbbdbb4a39676cd080858a1);
#
#
#             var icon_67beedc1c20e6ca0c3afffc9b7e0e3f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aeaa4714a00d945ba6b32b9e2c00a278.setIcon(icon_67beedc1c20e6ca0c3afffc9b7e0e3f2);
#
#
#         var popup_fae42f1d852f2738e91df4991d719294 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7a86cb6f92bb25b7cb60ac8923549a4c = $(`&lt;div id=&quot;html_7a86cb6f92bb25b7cb60ac8923549a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 강남구  남부순환로 2718 (도곡2동)&lt;/div&gt;`)[0];
#                 popup_fae42f1d852f2738e91df4991d719294.setContent(html_7a86cb6f92bb25b7cb60ac8923549a4c);
#
#
#
#         marker_aeaa4714a00d945ba6b32b9e2c00a278.bindPopup(popup_fae42f1d852f2738e91df4991d719294)
#         ;
#
#
#
#
#             marker_aeaa4714a00d945ba6b32b9e2c00a278.bindTooltip(
#                 `&lt;div&gt;
#                      현대오일뱅크 도곡셀프주유소(현대오일뱅크)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_12564bdfacf7c80cc4071e7333acc556 = L.marker(
#                 [37.4840308926021, 127.094990086002],
#                 {}
#             ).addTo(map_fba17acabbbbdbb4a39676cd080858a1);
#
#
#             var icon_5ceeac89eee8c53dc9d56affddfb0694 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-tint&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_12564bdfacf7c80cc4071e7333acc556.setIcon(icon_5ceeac89eee8c53dc9d56affddfb0694);
#
#
#         var popup_7dca3d70671b06dfb2dcb1e922760a65 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_29ac6f0e4ec4e6c1ba9550b4ffec5320 = $(`&lt;div id=&quot;html_29ac6f0e4ec4e6c1ba9550b4ffec5320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 강남구 광평로 202

# %% [markdown]
# ### 단계구분도

# %%
# 자치구 컬럼 만들기
lis = []
for i in df.index:
    lis.append(df.주소.loc[i].split()[1])
df['자치구'] = lis

# %%
# 구별 주유소 갯수 구하기
df_gu = df.groupby('자치구').count()['상호']

# %%
geo_data = json.load(open('skorea_municipalities_geo_simple.json', encoding='utf-8'))

# %%
# 지도
map = folium.Map(location=[37.581, 126.986], zoom_start=11, tiles='Stamen Toner')

folium.Choropleth(geo_data=geo_data, 
                  data=df_gu, 
                  columns=('자치구', '지역'), 
                  fill_color='YlOrRd', 
                  key_on='feature.id',
                  legended_name='주유소 수').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0c5f7f48e1f73916196a7e972988ade {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0c5f7f48e1f73916196a7e972988ade&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0c5f7f48e1f73916196a7e972988ade = L.map(
#                 &quot;map_e0c5f7f48e1f73916196a7e972988ade&quot;,
#                 {
#                     center: [37.581, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f92ee78f60e3c9a0af3df954a539726f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e0c5f7f48e1f73916196a7e972988ade);
#
#
#             var choropleth_7285c5b2ee4466cfb51adca70cc2b8d8 = L.featureGroup(
#                 {}
#             ).addTo(map_e0c5f7f48e1f73916196a7e972988ade);
#
#
#         function geo_json_ef7de602ea46a2674e28a4e3360a117e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ef7de602ea46a2674e28a4e3360a117e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ef7de602ea46a2674e28a4e3360a117e = L.geoJson(null, {
#                 onEachFeature: geo_json_ef7de602ea46a2674e28a4e3360a117e_onEachFeature,
#
#                 style: geo_json_ef7de602ea46a2674e28a4e3360a117e_styler,
#         });
#
#         function geo_json_ef7de602ea46a2674e28a4e3360a117e_add (data) {
#             geo_json_ef7de602ea46a2674e28a4e3360a117e
#                 .addData(data)
#                 .addTo(choropleth_7285c5b2ee4466cfb51adca70cc2b8d8);
#         }
#             geo_json_ef7de602ea46a2674e28a4e3360a117e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.11167

# %% [markdown]
# ### 지도 완성

# %%
# 지도
map = folium.Map(location=[37.581, 126.986], zoom_start=11)

#단계구분도
folium.Choropleth(geo_data=geo_data, 
                  data=df_gu, 
                  columns=('자치구', '지역'), 
                  fill_color='YlOrRd', 
                  key_on='feature.id',
                  legended_name='주유소 수').add_to(map)
#장소 표시
for i in df.index:
    try:
        road_addr = df['주소'].loc[i]
        station_name = df['상호'].loc[i]
        station_type = df['상표'].loc[i]
        url = f'{search_url}?query={quote(road_addr)}'
        result = requests.get(url, headers={"Authorization": f"KakaoAK {api_key}"}).json()
        lng = float(result['documents'][0]['x'])
        lat = float(result['documents'][0]['y'])
        folium.Marker(
            location = [lat, lng], 
            popup = folium.Popup(road_addr, max_width=200),
            tooltip = (station_name+f"({station_type})"), 
            icon = folium.Icon(color = 'black', icon = 'glyphicon glyphicon-tint')
        ).add_to(map)
    except:
        print(station_name)
title = "<h3 align = 'center' style = 'font-size:20px'> 서울자치구별 주유소 현황</h3>"
map.get_root().html.add_child(folium.Element(title))
map
# Out:
# (주)만성상사 대흥주유소
# 성원이앤에스(주)영등포지점
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cb5d5f191e977f24c4115eeddbd11b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align = &#x27;center&#x27; style = &#x27;font-size:20px&#x27;&gt; 서울자치구별 주유소 현황&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cb5d5f191e977f24c4115eeddbd11b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cb5d5f191e977f24c4115eeddbd11b3 = L.map(
#                 &quot;map_2cb5d5f191e977f24c4115eeddbd11b3&quot;,
#                 {
#                     center: [37.581, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5268dcab6bbb0b191b6cd6610cd93db4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cb5d5f191e977f24c4115eeddbd11b3);
#
#
#             var choropleth_c17cb016ab0624726ed60406dee4de9d = L.featureGroup(
#                 {}
#             ).addTo(map_2cb5d5f191e977f24c4115eeddbd11b3);
#
#
#         function geo_json_93f394bef2d145985f1b5ce7b0e9cbae_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_93f394bef2d145985f1b5ce7b0e9cbae_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_93f394bef2d145985f1b5ce7b0e9cbae = L.geoJson(null, {
#                 onEachFeature: geo_json_93f394bef2d145985f1b5ce7b0e9cbae_onEachFeature,
#
#                 style: geo_json_93f394bef2d145985f1b5ce7b0e9cbae_styler,
#         });
#
#         function geo_json_93f394bef2d145985f1b5ce7b0e9cbae_add (data) {
#             geo_json_93f394bef2d145985f1b5ce7b0e9cbae
#                 .addData(data)
#                 .addTo(choropleth_c17cb016ab0624726ed60406dee4de9d);
#         }
#             geo_json_93f394bef2d145985f1b5ce7b0e9cbae_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.142060584

# %%
map.save('./서울주유소현황.html')
