# %% [markdown]
# # 멜론차트 크롤링

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = "https://www.melon.com/chart/"
header = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
req = requests.get(url, headers=header)
soup = BeautifulSoup(req.text, 'html.parser')

# %% [markdown]
# ## 1. 필요한 데이터 찾기

# %%
# 곡들이 담겨져 있는 태그를 리스트로 저장
song_list = soup.find('table').select('tr.lst50') + soup.find('table').select('tr.lst100')
# Out:
# [<tr class="lst50" data-song-no="35945927" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Ditto 곡 선택" type="checkbox" value="35945927"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11127145');" title="NewJeans 'OMG'">
#  <img alt="NewJeans 'OMG' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/27/145/11127145_20230102135733_500.jpg/melon/resize/120/quality/80/optimize" width="60">
#  <span class="bg_album_frame"></span>
#  </img></a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35945927');" title="Ditto 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35945927);" title="Ditto 재생">Ditto</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11127145');" title="NewJeans 'OMG' - 페이지 이동">NewJeans 'OMG'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35945927" title="Ditto 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35945927);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35945927');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35945927', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35945927','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35985167" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="OMG 곡 선택" type="checkbox" value="35985167"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">2</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11127145');" title="NewJeans 'OMG'">
#  <img alt="NewJeans 'OMG' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/27/145/11127145_20230102135733_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35985167');" title="OMG 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35985167);" title="OMG 재생">OMG</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11127145');" title="NewJeans 'OMG' - 페이지 이동">NewJeans 'OMG'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35985167" title="OMG 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35985167);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35985167');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35985167', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35985167','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35454426" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Hype boy 곡 선택" type="checkbox" value="35454426"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">3</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans'">
#  <img alt="NewJeans 1st EP 'New Jeans' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/11/565/11011565_20220801102637_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35454426');" title="Hype boy 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35454426);" title="Hype boy 재생">Hype boy</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans' - 페이지 이동">NewJeans 1st EP 'New Jeans'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35454426" title="Hype boy 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35454426);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35454426');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35454426', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35454426','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="34819473" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="사건의 지평선 곡 선택" type="checkbox" value="34819473"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">4</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10903868');" title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition'">
#  <img alt="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/03/868/10903868_20220330103544_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34819473');" title="사건의 지평선 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',34819473);" title="사건의 지평선 재생">사건의 지평선</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('203912');" title="윤하 (YOUNHA) - 페이지 이동">윤하 (YOUNHA)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('203912');" title="윤하 (YOUNHA) - 페이지 이동">윤하 (YOUNHA)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10903868');" title="YOUNHA 6th Album Repackage 'END THEORY : Final Edition' - 페이지 이동">YOUNHA 6th Album Repackage 'END THEORY : Final Edition'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="34819473" title="사건의 지평선 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',34819473);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('34819473');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '34819473', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '34819473','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35729104" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="ANTIFRAGILE 곡 선택" type="checkbox" value="35729104"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">5</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11078496');" title="ANTIFRAGILE">
#  <img alt="ANTIFRAGILE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/78/496/11078496_20221014153848_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35729104');" title="ANTIFRAGILE 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35729104);" title="ANTIFRAGILE 재생">ANTIFRAGILE</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11078496');" title="ANTIFRAGILE - 페이지 이동">ANTIFRAGILE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35729104" title="ANTIFRAGILE 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35729104);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35729104');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35729104', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35729104','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35931532" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Candy 곡 선택" type="checkbox" value="35931532"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">6</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11124139');" title="Candy - Winter Special Mini Album">
#  <img alt="Candy - Winter Special Mini Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/24/139/11124139_20221215162633_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35931532');" title="Candy 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35931532);" title="Candy 재생">Candy</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('1066419');" title="NCT DREAM - 페이지 이동">NCT DREAM</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1066419');" title="NCT DREAM - 페이지 이동">NCT DREAM</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11124139');" title="Candy - Winter Special Mini Album - 페이지 이동">Candy - Winter Special Mini Album</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35931532" title="Candy 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35931532);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35931532');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35931532', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35931532','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35937396" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="NOT SORRY (Feat. pH-1) (Prod. by Slom) 곡 선택" type="checkbox" value="35937396"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">7</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11125247');" title="쇼미더머니 11 Episode 3">
#  <img alt="쇼미더머니 11 Episode 3 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/25/247/11125247_20221216121651_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35937396');" title="NOT SORRY (Feat. pH-1) (Prod. by Slom) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35937396);" title="NOT SORRY (Feat. pH-1) (Prod. by Slom) 재생">NOT SORRY (Feat. pH-1) (Prod. by Slom)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('2636153');" title="이영지 - 페이지 이동">이영지</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2636153');" title="이영지 - 페이지 이동">이영지</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11125247');" title="쇼미더머니 11 Episode 3 - 페이지 이동">쇼미더머니 11 Episode 3</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35937396" title="NOT SORRY (Feat. pH-1) (Prod. by Slom) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35937396);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35937396');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35937396', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35937396','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35454425" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Attention 곡 선택" type="checkbox" value="35454425"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">8</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans'">
#  <img alt="NewJeans 1st EP 'New Jeans' - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/11/565/11011565_20220801102637_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35454425');" title="Attention 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35454425);" title="Attention 재생">Attention</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3114174');" title="NewJeans - 페이지 이동">NewJeans</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11011565');" title="NewJeans 1st EP 'New Jeans' - 페이지 이동">NewJeans 1st EP 'New Jeans'</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35454425" title="Attention 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35454425);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35454425');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35454425', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35454425','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35546497" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="After LIKE 곡 선택" type="checkbox" value="35546497"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">9</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11034298');" title="After LIKE">
#  <img alt="After LIKE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/34/298/11034298_20220822101843_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35546497');" title="After LIKE 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35546497);" title="After LIKE 재생">After LIKE</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11034298');" title="After LIKE - 페이지 이동">After LIKE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35546497" title="After LIKE 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35546497);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35546497');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35546497', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35546497','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="34061322" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="사랑은 늘 도망가 곡 선택" type="checkbox" value="34061322"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">10</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10735654');" title="신사와 아가씨 OST Part.2">
#  <img alt="신사와 아가씨 OST Part.2 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/107/35/654/10735654_20211008114339_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34061322');" title="사랑은 늘 도망가 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',34061322);" title="사랑은 늘 도망가 재생">사랑은 늘 도망가</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10735654');" title="신사와 아가씨 OST Part.2 - 페이지 이동">신사와 아가씨 OST Part.2</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="34061322" title="사랑은 늘 도망가 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',34061322);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('34061322');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '34061322', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '34061322','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35730562" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Nxde 곡 선택" type="checkbox" value="35730562"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">11</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11078852');" title="I love">
#  <img alt="I love - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/78/852/11078852_20221017102947_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35730562');" title="Nxde 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35730562);" title="Nxde 재생">Nxde</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11078852');" title="I love - 페이지 이동">I love</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35730562" title="Nxde 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35730562);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35730562');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35730562', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35730562','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="34847378" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="LOVE DIVE 곡 선택" type="checkbox" value="34847378"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">12</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10909179');" title="LOVE DIVE">
#  <img alt="LOVE DIVE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/09/179/10909179_20220405103521_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34847378');" title="LOVE DIVE 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',34847378);" title="LOVE DIVE 재생">LOVE DIVE</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10909179');" title="LOVE DIVE - 페이지 이동">LOVE DIVE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="34847378" title="LOVE DIVE 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',34847378);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('34847378');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '34847378', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '34847378','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="34908740" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="우리들의 블루스 곡 선택" type="checkbox" value="34908740"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">13</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO">
#  <img alt="IM HERO - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/109/23/444/10923444_20220502140600_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('34908740');" title="우리들의 블루스 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',34908740);" title="우리들의 블루스 재생">우리들의 블루스</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10923444');" title="IM HERO - 페이지 이동">IM HERO</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="34908740" title="우리들의 블루스 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',34908740);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('34908740');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '34908740', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '34908740','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35888871" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="마이웨이 (MY WAY) (Prod. R.Tee) 곡 선택" type="checkbox" value="35888871"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">14</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11115007');" title="쇼미더머니 11 Episode 1">
#  <img alt="쇼미더머니 11 Episode 1 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/15/007/11115007_20221202105416_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35888871');" title="마이웨이 (MY WAY) (Prod. R.Tee) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35888871);" title="마이웨이 (MY WAY) (Prod. R.Tee) 재생">마이웨이 (MY WAY) (Prod. R.Tee)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('786499');" title="저스디스 (JUSTHIS) - 페이지 이동">저스디스 (JUSTHIS)</a>, <a href="javascript:melon.link.goArtistDetail('633071');" title="R.Tee - 페이지 이동">R.Tee</a>, <a href="javascript:melon.link.goArtistDetail('789943');" title="던말릭 (DON MALIK) - 페이지 이동">던말릭 (DON MALIK)</a>, <a href="javascript:melon.link.goArtistDetail('2190397');" title="허성현 (Huh) - 페이지 이동">허성현 (Huh)</a>, <a href="javascript:melon.link.goArtistDetail('2741140');" title="KHAN - 페이지 이동">KHAN</a>, <a href="javascript:melon.link.goArtistDetail('774027');" title="맥대디 (Mckdaddy) - 페이지 이동">맥대디 (Mckdaddy)</a>, <a href="javascript:melon.link.goArtistDetail('1628539');" title="로스 (Los) - 페이지 이동">로스 (Los)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('786499');" title="저스디스 (JUSTHIS) - 페이지 이동">저스디스 (JUSTHIS)</a>, <a href="javascript:melon.link.goArtistDetail('633071');" title="R.Tee - 페이지 이동">R.Tee</a>, <a href="javascript:melon.link.goArtistDetail('789943');" title="던말릭 (DON MALIK) - 페이지 이동">던말릭 (DON MALIK)</a>, <a href="javascript:melon.link.goArtistDetail('2190397');" title="허성현 (Huh) - 페이지 이동">허성현 (Huh)</a>, <a href="javascript:melon.link.goArtistDetail('2741140');" title="KHAN - 페이지 이동">KHAN</a>, <a href="javascript:melon.link.goArtistDetail('774027');" title="맥대디 (Mckdaddy) - 페이지 이동">맥대디 (Mckdaddy)</a>, <a href="javascript:melon.link.goArtistDetail('1628539');" title="로스 (Los) - 페이지 이동">로스 (Los)</a></span>
#  </div>
#  <div class="wrap_atist" style="display:none;">
#  <button class="button_icons etc more_down" data-control="dropdown" title="아티스트 더보기" type="button"><span class="none">아티스트명 더보기</span></button>
#  <div class="atist_view" style="display:none;">
#  <ul>
#  <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('786499');" title="저스디스 (JUSTHIS) 페이지 이동">저스디스 (JUSTHIS)</a></li>
#  <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('633071');" title="R.Tee 페이지 이동">R.Tee</a></li>
#  <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('789943');" title="던말릭 (DON MALIK) 페이지 이동">던말릭 (DON MALIK)</a></li>
#  <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('2190397');" title="허성현 (Huh) 페이지 이동">허성현 (Huh)</a></li>
#  <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('2741140');" title="KHAN 페이지 이동">KHAN</a></li>
#  <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('774027');" title="맥대디 (Mckdaddy) 페이지 이동">맥대디 (Mckdaddy)</a></li>
#  <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('1628539');" title="로스 (Los) 페이지 이동">로스 (Los)</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11115007');" title="쇼미더머니 11 Episode 1 - 페이지 이동">쇼미더머니 11 Episode 1</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35888871" title="마이웨이 (MY WAY) (Prod. R.Tee) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35888871);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35888871');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35888871', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35888871','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst50" data-song-no="35595136" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="새삥 (Prod. ZICO) (Feat. 호미들) 곡 선택" type="checkbox" value="35595136"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">15</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11045985');" title="스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)">
#  <img alt="스트릿 맨 파이터(SMF) Original Vol.3 (계급미션) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/45/985/11045985_20220905151107_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35595136');" title="새삥 (Prod. ZICO) (Feat. 호미들) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35595136);" title="새삥 (Prod. ZICO) (Feat. 호미들) 재생">새삥 (Prod. ZICO) (Feat. 호미들)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('602056');" title="지코 (ZICO) - 페이지 이동">지코 (ZICO)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('602056');" title="지코 (ZICO) - 페이지 이동">지코 (ZICO)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11045985');" title="스트릿 맨 파이터(SMF) Original Vol.3 (계급미션) - 페이지 이동">스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35595136" title="새삥 (Prod. ZICO) (Feat. 호미들) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35595136);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35595136');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
# ...
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35897670');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35897670', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '35897670','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="33359309" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Off My Face 곡 선택" type="checkbox" value="33359309"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">96</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10580103');" title="Justice (The Complete Edition)">
#  <img alt="Justice (The Complete Edition) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/105/80/103/10580103_20211008114642_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('33359309');" title="Off My Face 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',33359309);" title="Off My Face 재생">Off My Face</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('420621');" title="Justin Bieber - 페이지 이동">Justin Bieber</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('420621');" title="Justin Bieber - 페이지 이동">Justin Bieber</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10580103');" title="Justice (The Complete Edition) - 페이지 이동">Justice (The Complete Edition)</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="33359309" title="Off My Face 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',33359309);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('33359309');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '33359309', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '33359309','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="35690912" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="나의 목소리로 곡 선택" type="checkbox" value="35690912"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">97</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11069174');" title="나의 목소리로">
#  <img alt="나의 목소리로 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/110/69/174/11069174_20220930140119_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35690912');" title="나의 목소리로 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35690912);" title="나의 목소리로 재생">나의 목소리로</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('720018');" title="김호중 - 페이지 이동">김호중</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11069174');" title="나의 목소리로 - 페이지 이동">나의 목소리로</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35690912" title="나의 목소리로 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35690912);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35690912');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35690912', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35690912','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="35966218" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="이 소설의 끝을 다시 써보려 해 곡 선택" type="checkbox" value="35966218"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">98</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11132201');" title="이 소설의 끝을 다시 써보려 해">
#  <img alt="이 소설의 끝을 다시 써보려 해 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/32/201/11132201_20221227152925_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35966218');" title="이 소설의 끝을 다시 써보려 해 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35966218);" title="이 소설의 끝을 다시 써보려 해 재생">이 소설의 끝을 다시 써보려 해</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('51893');" title="테이 - 페이지 이동">테이</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('51893');" title="테이 - 페이지 이동">테이</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11132201');" title="이 소설의 끝을 다시 써보려 해 - 페이지 이동">이 소설의 끝을 다시 써보려 해</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35966218" title="이 소설의 끝을 다시 써보려 해 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35966218);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35966218');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35966218', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35966218','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="35931536" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="문 (Moon) 곡 선택" type="checkbox" value="35931536"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">99</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11124139');" title="Candy - Winter Special Mini Album">
#  <img alt="Candy - Winter Special Mini Album - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/24/139/11124139_20221215162633_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('35931536');" title="문 (Moon) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',35931536);" title="문 (Moon) 재생">문 (Moon)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('1066419');" title="NCT DREAM - 페이지 이동">NCT DREAM</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1066419');" title="NCT DREAM - 페이지 이동">NCT DREAM</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('11124139');" title="Candy - Winter Special Mini Album - 페이지 이동">Candy - Winter Special Mini Album</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="35931536" title="문 (Moon) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',35931536);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('35931536');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '35931536', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '35931536','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>,
#  <tr class="lst100" data-song-no="33480898" id="lst100">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="신호등 곡 선택" type="checkbox" value="33480898"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">100</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10607796');" title="신호등">
#  <img alt="신호등 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/106/07/796/10607796_20210513201807_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('33480898');" title="신호등 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',33480898);" title="신호등 재생">신호등</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('2138620');" title="이무진 - 페이지 이동">이무진</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2138620');" title="이무진 - 페이지 이동">이무진</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10607796');" title="신호등 - 페이지 이동">신호등</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="1000002721" data-song-no="33480898" title="신호등 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play" onclick="melon.play.playSong('1000002721',33480898);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap" onclick="melon.play.addPlayList('33480898');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '33480898', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '33480898','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  </tr>]

# %%
# 첫 곡을 가져오기
song = song_list[0]

# %%
# 순위
rank = int(song.find_all('td')[1].select_one('.rank').text)
rank
# Out:
# 1

# %%
# 제목
title = song.find_all('td')[5].select_one('.rank01').find('a').text
title
# Out:
# 'Ditto'

# %%
# 아티스트 이름
artist = song.find_all('td')[5].select_one('.rank02').find('a').text
artist
# Out:
# 'NewJeans'

# %%
# 앨범명
album = song.find_all('td')[6].select_one('.rank03').find('a').text
album
# Out:
# "NewJeans 'OMG'"

# %% [markdown]
# ## 2. 리스트에 저장

# %%
chart = []
for song in song_list:
    rank = int(song.find_all('td')[1].select_one('.rank').text) # 순위
    title = song.find_all('td')[5].select_one('.rank01').find('a').text # 제목
    artist = song.find_all('td')[5].select_one('.rank02').find('a').text # 아티스트 이름
    album = song.find_all('td')[6].select_one('.rank03').find('a').text # 앨범명
    chart.append({
        '순위' : rank, '제목' : title, '가수' : artist, '앨범' : album
    })

# %% [markdown]
# ## 3. 데이터 프레임으로 변환

# %%
df_melon = pd.DataFrame(chart)

# %%
df_melon
# Out:
#      순위                 제목                  가수  \
# 0     1              Ditto            NewJeans
# 1     2                OMG            NewJeans
# 2     3           Hype boy            NewJeans
# 3     4            사건의 지평선         윤하 (YOUNHA)
# 4     5        ANTIFRAGILE  LE SSERAFIM (르세라핌)
# ..  ...                ...                 ...
# 95   96        Off My Face       Justin Bieber
# 96   97            나의 목소리로                 김호중
# 97   98  이 소설의 끝을 다시 써보려 해                  테이
# 98   99           문 (Moon)           NCT DREAM
# 99  100                신호등                 이무진
#
#                                                    앨범
# 0                                      NewJeans 'OMG'
# 1                                      NewJeans 'OMG'
# 2                         NewJeans 1st EP 'New Jeans'
# 3   YOUNHA 6th Album Repackage 'END THEORY : Final...
# 4                                         ANTIFRAGILE
# ..                                                ...
# 95                     Justice (The Complete Edition)
# 96                                            나의 목소리로
# 97                                  이 소설의 끝을 다시 써보려 해
# 98                  Candy - Winter Special Mini Album
# 99                                                신호등
#
# [100 rows x 4 columns]

# %% [markdown]
# ## 4. csv 파일로 변환

# %%
df_melon.to_csv('멜론차트TOP100.csv')

# %% [markdown]
# # 지니차트 크롤링

# %%
site = "https://www.genie.co.kr/chart/"
url = f"{site}top200?ditc=D&ymd=20230111&hh=17&rtm=Y&pg={4}"
header = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
req = requests.get(url, headers=header)
soup = BeautifulSoup(req.text, 'html.parser')

# %% [markdown]
# ## 1. 필요한 데이터 찾기

# %%
# 곡들이 담겨져 있는 태그를 리스트로 저장
song_list = soup.select_one('.list-wrap').find('tbody').find_all('tr')

# %%
# 한 곡을 가져오기
song = song_list[32]

# %%
# 순위
rank = song.select_one('.number').text.split(" ")[0].strip()
rank
# Out:
# '183'

# %%
# 제목
title = song.select_one('.info > .title').text.strip().split('19금')[-1].strip()
title
# Out:
# 'abcdefu'

# %%
# 아티스트 이름
artist = song.select_one('.info > .artist').text.strip()
artist
# Out:
# 'GAYLE'

# %%
# 앨범명
album = song.select_one('.info > .albumtitle').text.strip()
album
# Out:
# 'abcdefu'

# %% [markdown]
# ## 2. 리스트에 저장

# %% [markdown]
# ### 2-1. 첫 페이지

# %%
chart = []
for song in soup.select_one('.list-wrap').find('tbody').find_all('tr'):
    rank = song.select_one('.number').text.split(" ")[0].strip() # 순위
    title = song.select_one('.info > .title').text.strip().split('19금')[-1].strip() # 제목
    artist = song.select_one('.info > .artist').text.strip() # 아티스트 이름
    album = song.select_one('.info > .albumtitle').text.strip() # 앨범명
    chart.append({
        '순위' : rank, '제목' : title, '가수' : artist, '앨범' : album
    })

# %%
df1 = pd.DataFrame(chart)
df1
# Out:
#      순위                                                 제목  \
# 0    51                                           FEARLESS
# 1    52                                             ELEVEN
# 2    53                                           The Drum
# 3    54                                             그대를 알고
# 4    55                                               Stay
# 5    56                               정이라고 하자 (Feat. 10CM)
# 6    57                                      Made You Look
# 7    58                                                잘가요
# 8    59                                            딱 10CM만
# 9    60                                        우린 그렇게 사랑해서
# 10   61                                            LOVE me
# 11   62                                                 고백
# 12   63                                            언제나 사랑해
# 13   64                      Loving You Girl (Feat. Hkeem)
# 14   65                                     Beautiful Liar
# 15   66                                                신호등
# 16   67              모든 날, 모든 순간 (Every day, Every Moment)
# 17   68                                    strawberry moon
# 18   69              That That (Prod. & Feat. SUGA of BTS)
# 19   70                                     밤하늘의 별을 (2020)
# 20   71                                       주저하는 연인들을 위해
# 21   72                                               2002
# 22   73                               봄여름가을겨울 (Still Life)
# 23   74                                    떠나보낼 준비해 둘걸 그랬어
# 24   75                                           Dynamite
# 25   76                                        Dangerously
# 26   77                                내 기쁨은 너가 벤틀리를 끄는 거야
# 27   78                         너의 번호를 누르고 (Prod. by 영화처럼)
# 28   79                                         Love story
# 29   80                                         Bad Habits
# 30   81                                    도깨비불 (Illusion)
# 31   82                                  그댄 행복에 살텐데 (2022)
# 32   83                                             Butter
# 33   84                                            Snowman
# 34   85                                                팡파레
# 35   86              위하여 (We Higher) (Prod. by GroovyRoom)
# 36   87                                             Unholy
# 37   88                                     새벽에 걸려온 너의 전화는
# 38   89                                         그중에 그대를 만나
# 39   90                               LAW (Prod. by Czaer)
# 40   91                                             MY BAG
# 41   92  눈 (EYE) (Feat. BIG Naughty & 저스디스 (JUSTHIS)) (...
# 42   93                                          FOREVER 1
# 43   94                                          Celebrity
# 44   95                                                Bad
# 45   96                                           SNEAKERS
# 46   97         회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)
# 47   98                                     OHAYO MY NIGHT
# 48   99                                       첫눈처럼 너에게 가겠다
# 49  100                   Stronger (What Doesn't Kill You)
#
#                                                    가수  \
# 0                                  LE SSERAFIM (르세라핌)
# 1                                           IVE (아이브)
# 2                                         Alan Walker
# 3                                                 송하예
# 4                       The Kid LAROI & Justin Bieber
# 5                                   BIG Naughty (서동현)
# 6                                      Meghan Trainor
# 7                                                  주호
# 8                            10CM & BIG Naughty (서동현)
# 9                                 강민경 (다비치) & 잔나비 최정훈
# 10                                          BE'O (비오)
# 11                                   멜로망스 (MeloMance)
# 12                                        케이시 (Kassy)
# 13                                        Peder Elias
# 14                                              몬스타엑스
# 15                                                이무진
# 16                                                 폴킴
# 17                                           아이유 (IU)
# 18                                           싸이 (Psy)
# 19                                                 경서
# 20                                                잔나비
# 21                                         Anne-Marie
# 22                                       BIGBANG (빅뱅)
# 23                                                임한별
# 24                                              방탄소년단
# 25                                       Charlie Puth
# 26                                                김승민
# 27                                                #안녕
# 28                                             볼빨간사춘기
# 29                                         Ed Sheeran
# 30                                              aespa
# 31                                                최유리
# 32                                              방탄소년단
# 33                                                Sia
# 34                                                다비치
# 35  그루비룸 (GroovyRoom) & 릴보이 (lIlBOI) & Blase (블라세)...
# 36                             Sam Smith & Kim Petras
# 37                                                한동근
# 38                                                김호중
# 39                                    비비 (BIBI) & 윤미래
# 40                                            (여자)아이들
# 41                                    던말릭 (DON MALIK)
# 42                           소녀시대 (GIRLS' GENERATION)
# 43                                           아이유 (IU)
# 44                                        Christopher
# 45                                          ITZY (있지)
# 46                                           sokodomo
# 47                               디핵 (D-Hack) & PATEKO
# 48                                        에일리 (Ailee)
# 49                                     Kelly Clarkson
#
#                                                 앨범
# 0                                         FEARLESS
# 1                                           ELEVEN
# 2                               Walkerverse, Pt. I
# 3                                           그대를 알고
# 4                                             Stay
# 5                                          정이라고 하자
# 6                                   Takin' It Back
# 7                                              잘가요
# 8                                          딱 10CM만
# 9                                      우린 그렇게 사랑해서
# 10                                         LOVE me
# 11                                       세 번째 '고백'
# 12                            조영수 리메이크 프로젝트 Part.2
# 13                               Love & Loneliness
# 14                                          REASON
# 15                                             신호등
# 16            '키스 먼저 할까요?' OST Part. 3 (SBS 월화드라마)
# 17                                 strawberry moon
# 18                                             싸다9
# 19                                  밤하늘의 별을 (2020)
# 20                                              전설
# 21                        Speak Your Mind (Deluxe)
# 22                            봄여름가을겨울 (Still Life)
# 23                                 떠나보낼 준비해 둘걸 그랬어
# 24                         Dynamite (DayTime Ver.)
# 25                Nine Track Mind (Deluxe Edition)
# 26                        PROTOTYPE RESEARCH #0063
# 27                                      너의 번호를 누르고
# 28                                           Seoul
# 29                                               =
# 30                      Girls - The 2nd Mini Album
# 31                               그댄 행복에 살텐데 (2022)
# 32                                          Butter
# 33  Everyday Is Christmas (Snowman Deluxe Edition)
# 34                                     Season Note
# 35                              쇼미더머니 11 Episode 1
# 36                                          Unholy
# 37                                         미련을 말하는
# 38                            삼남매가 용감하게 OST Part.1
# 39            스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)
# 40                                     I NEVER DIE
# 41                              쇼미더머니 11 Episode 3
# 42                       FOREVER 1 - The 7th Album
# 43                            IU 5th Album 'LILAC'
# 44                               Under the Surface
# 45                                       CHECKMATE
# 46                              쇼미더머니 10 Episode 2
# 47                                  OHAYO MY NIGHT
# 48                      도깨비 OST Part 9 (tvN 금토드라마)
# 49                Stronger (What Doesn't Kill You)

# %% [markdown]
# ### 2-2. 모든 페이지

# %%
chart = []
for i in range(1, 5): # 5 페이지 모두 불러오기
    site = "https://www.genie.co.kr/chart/"
    url = f"{site}top200?ditc=D&ymd=20230111&hh=17&rtm=Y&pg={i}"
    header = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
    req = requests.get(url, headers=header)
    soup = BeautifulSoup(req.text, 'html.parser')
    
    for song in soup.select_one('.list-wrap').find('tbody').find_all('tr'):
        rank = song.select_one('.number').text.split(" ")[0].strip() # 순위
        title = song.select_one('.info > .title').text.strip().split('19금')[-1].strip() # 제목
        artist = song.select_one('.info > .artist').text.strip() # 아티스트 이름
        album = song.select_one('.info > .albumtitle').text.strip() # 앨범명
        chart.append({
            '순위' : rank, '제목' : title, '가수' : artist, '앨범' : album
        })

# %% [markdown]
# ## 3. 데이터 프레임으로 변환

# %%
df_genie = pd.DataFrame(chart)
df_genie.tail(20)
# Out:
#       순위                                                 제목  \
# 180  181                                  늦은 밤 너의 집 앞 골목길에서
# 181  182                                      Way Back Home
# 182  183                                            abcdefu
# 183  184                                   너에게 못했던 내 마지막 말은
# 184  185                                                 시작
# 185  186                                         안녕 (Hello)
# 186  187                                          parachute
# 187  188                                       O Tannenbaum
# 188  189                     WE (Feat. 박재범) (Prod. by Slom)
# 189  190                                       Light Switch
# 190  191                                              Crazy
# 191  192                                    비가 오는 날엔 (2021)
# 192  193                                       롤린 (Rollin')
# 193  194                                             소주 한 잔
# 194  195                                            그래서 그대는
# 195  196                                               웃는거야
# 196  197  사랑하긴 했었나요 스쳐가는 인연이었나요 짧지않은 우리 함께했던 시간들이 자꾸 내 마...
# 197  198                                            Say Yes
# 198  199                                         추억은 사랑을 닮아
# 199  200                                 뜨거운 안녕 (Feat. 성시경)
#
#                                                     가수  \
# 180                                                 노을
# 181                                          숀 (SHAUN)
# 182                                              GAYLE
# 183                                                다비치
# 184                                          가호 (Gaho)
# 185                                           조이 (JOY)
# 186                                             John K
# 187                                                김호중
# 188  이영지 & 토이고 (toigo) & 제이켠 (J'Kyun) & 잠비노 (Jambin...
# 189                                       Charlie Puth
# 190                                     Gnarls Barkley
# 191                                        헤이즈 (Heize)
# 192                               브레이브걸스 (Brave girls)
# 193                                                임창정
# 194                                                이영현
# 195                                               21학번
# 196                                                잔나비
# 197                                    로꼬 & 펀치 (Punch)
# 198                                                박효신
# 199                                           싸이 (Psy)
#
#                                                     앨범
# 180                                  늦은 밤 너의 집 앞 골목길에서
# 181                                               Take
# 182                                            abcdefu
# 183                                   너에게 못했던 내 마지막 말은
# 184                    이태원 클라쓰 OST Part.2 (JTBC 금토드라마)
# 185                         안녕 (Hello) - Special Album
# 186                             love ＋ everything else
# 187                                           PANORAMA
# 188                                 쇼미더머니 11 Episode 1
# 189                                            CHARLIE
# 190  St. Elsewhere (I-Tunes Premium Bundle With Bon...
# 191                                    비가 오는 날엔 (2021)
# 192                                            Rollin'
# 193                                                Bye
# 194                                            그래서 그대는
# 195                                               웃는거야
# 196                                             봉춤을 추네
# 197              달의 연인 - 보보경심 려 OST Part 2 (SBS 월화드라마)
# 198                                  The Breeze Of Sea
# 199                                        싸이6甲 Part.1

# %% [markdown]
# ## 4. csv 파일로 변환

# %%
df_genie.to_csv('지니차트TOP100.csv')

# %% [markdown]
# # 벅스차트 크롤링

# %%
url = "https://music.bugs.co.kr/chart"
header = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
req = requests.get(url, headers=header)
soup = BeautifulSoup(req.text, 'html.parser')

# %% [markdown]
# ## 1. 필요한 데이터 찾기

# %%
# 곡들이 담겨져 있는 태그를 리스트로 저장
song_list = soup.select_one('#CHARTrealtime').find('tbody').find_all('tr')

# %%
# 한 곡을 가져오기
song = song_list[19]

# %%
# 순위
rank = int(song.select_one('.ranking > strong').text)
rank
# Out:
# 20

# %%
# 제목
title = song.select_one('.title').text.strip()
title
# Out:
# 'Pink Venom'

# %%
# 아티스트 이름
artist = song.select_one('.artist').text.strip().split('\n')[0]
artist
# Out:
# 'BLACKPINK'

# %%
# 앨범명
album = song.select_one('.album').text.strip()
album
# Out:
# 'BORN PINK'

# %% [markdown]
# ## 2. 리스트에 저장

# %%
chart = []
for song in soup.select_one('#CHARTrealtime').find('tbody').find_all('tr'):
    rank = int(song.select_one('.ranking > strong').text) # 순위
    title = song.select_one('.title').text.strip() # 제목
    artist = song.select_one('.artist').text.strip().split('\n')[0] # 아티스트 이름
    album = song.select_one('.album').text.strip() # 앨범명
    chart.append({
            '순위' : rank, '제목' : title, '가수' : artist, '앨범' : album
        })

# %% [markdown]
# ## 3. 데이터 프레임으로 변환

# %%
df_bugs = pd.DataFrame(chart)
df_bugs.head(22)
# Out:
#     순위                                                 제목  \
# 0    1                                              Ditto
# 1    2                                                OMG
# 2    3                                           Hype Boy
# 3    4                                            사건의 지평선
# 4    5                                          Attention
# 5    6                                              Candy
# 6    7                                        ANTIFRAGILE
# 7    8                                         After LIKE
# 8    9             NOT SORRY (Feat. pH-1) (Prod. by Slom)
# 9   10                                        WHEN I MOVE
# 10  11                                          LOVE DIVE
# 11  12                                               Nxde
# 12  13                                          Shut Down
# 13  14                                             Cookie
# 14  15                      I Don’t Think That I Like Her
# 15  16                                              오르트구름
# 16  17                        새삥 (Prod. ZICO) (Feat. 호미들)
# 17  18                                      Made You Look
# 18  19                                           FEARLESS
# 19  20                                         Pink Venom
# 20  21                                             Unholy
# 21  22  Dreamers [Music from the FIFA World Cup Qatar ...
#
#                          가수                                                 앨범
# 0                  NewJeans                                     NewJeans 'OMG'
# 1                  NewJeans                                     NewJeans 'OMG'
# 2                  NewJeans                        NewJeans 1st EP 'New Jeans'
# 3            윤하(Younha/ユンナ)  YOUNHA 6th Album Repackage 'END THEORY : Final...
# 4                  NewJeans                        NewJeans 1st EP 'New Jeans'
# 5                 NCT DREAM                  Candy - Winter Special Mini Album
# 6        LE SSERAFIM (르세라핌)                                        ANTIFRAGILE
# 7                 IVE (아이브)                                         After LIKE
# 8                       이영지                                 쇼미더머니 11 Episode 3
# 9                  카라(Kara)                                         MOVE AGAIN
# 10                IVE (아이브)                                          LOVE DIVE
# 11                  (여자)아이들                                             I love
# 12                BLACKPINK                                          BORN PINK
# 13                 NewJeans                        NewJeans 1st EP 'New Jeans'
# 14      Charlie Puth(찰리 푸스)                      I Don’t Think That I Like Her
# 15           윤하(Younha/ユンナ)                      YOUNHA 6th Album 'END THEORY'
# 16                       지코               스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)
# 17  Meghan Trainor(메간 트레이너)                                     Takin' It Back
# 18       LE SSERAFIM (르세라핌)                                           FEARLESS
# 19                BLACKPINK                                          BORN PINK
# 20         Sam Smith(샘 스미스)                                             Unholy
# 21                       정국  Dreamers [Music from the FIFA World Cup Qatar ...

# %% [markdown]
# ## 4. csv 파일로 변환

# %%
df_bugs.to_csv('벅스차트TOP100.csv')
